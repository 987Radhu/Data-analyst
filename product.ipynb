# %% [markdown]
# <a href="https://colab.research.google.com/github/987Radhu/Data-analyst/blob/data-analyst/product.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/flipkart_sample1.csv")
df
# Out:
#                                          product_name           brand  \
# 0                 Alisha Solid Women's Cycling Shorts          Alisha
# 1                 FabHomeDecor Fabric Double Sofa Bed    FabHomeDecor
# 2                                          AW Bellies              AW
# 3                 Alisha Solid Women's Cycling Shorts          Alisha
# 4               Sicons All Purpose Arnica Dog Shampoo          Sicons
# 5   Eternal Gandhi Super Series Crystal Paper Weig...  Eternal Gandhi
# 6                 Alisha Solid Women's Cycling Shorts          Alisha
# 7                 FabHomeDecor Fabric Double Sofa Bed    FabHomeDecor
# 8   dilli bazaaar Bellies, Corporate Casuals, Casuals   dilli bazaaar
# 9                 Alisha Solid Women's Cycling Shorts          Alisha
# 10                                     Ladela Bellies          Ladela
# 11                             Carrel Printed Women's          Carrel
# ...

# %%
cols=df.keys()
data=[]
for ind in df.index:
  temp={}
  for col in cols:
    temp[col] = df[col][ind]
    data.append(temp)

    for x in data:
      print(x)
# Out:
# Streaming output truncated to the last 5000 lines.
# {'product_name': "Alisha Solid Women's Cycling Shorts", 'brand': 'Alisha', 'product_category_tree': '["Clothing ', 'qty': 14}
# {'product_name': "Alisha Solid Women's Cycling Shorts", 'brand': 'Alisha', 'product_category_tree': '["Clothing ', 'qty': 14}
# {'product_name': "Alisha Solid Women's Cycling Shorts", 'brand': 'Alisha', 'product_category_tree': '["Clothing ', 'qty': 14}
# {'product_name': 'FabHomeDecor Fabric Double Sofa Bed', 'brand': 'FabHomeDecor'}
# {'product_name': 'FabHomeDecor Fabric Double Sofa Bed', 'brand': 'FabHomeDecor'}
# {'product_name': "Alisha Solid Women's Cycling Shorts", 'brand': 'Alisha', 'product_category_tree': '["Clothing ', 'qty': 79}
# {'product_name': "Alisha Solid Women's Cycling Shorts", 'brand': 'Alisha', 'product_category_tree': '["Clothing ', 'qty': 79}
# {'product_name': "Alisha Solid Women's Cycling Shorts", 'brand': 'Alisha', 'product_category_tree': '["Clothing ', 'qty': 79}
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                          product_name           brand  \
# 0                 Alisha Solid Women's Cycling Shorts          Alisha
# 1                 FabHomeDecor Fabric Double Sofa Bed    FabHomeDecor
# 2                                          AW Bellies              AW
# 3                 Alisha Solid Women's Cycling Shorts          Alisha
# 4               Sicons All Purpose Arnica Dog Shampoo          Sicons
# 5   Eternal Gandhi Super Series Crystal Paper Weig...  Eternal Gandhi
# 6                 Alisha Solid Women's Cycling Shorts          Alisha
# 7                 FabHomeDecor Fabric Double Sofa Bed    FabHomeDecor
# 8   dilli bazaaar Bellies, Corporate Casuals, Casuals   dilli bazaaar
# 9                 Alisha Solid Women's Cycling Shorts          Alisha
# 10                                     Ladela Bellies          Ladela
# 11                             Carrel Printed Women's          Carrel
# ...
